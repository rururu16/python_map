# %%
# encoding: utf-8
import urllib.request
import requests
import pdb
import xmltodict
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd

KEY = "1fa61c56392e94a6"
COUNT = 100
# グルメサーチAPI
H_API = "https://webservice.recruit.co.jp/hotpepper/gourmet/v1/" #?key=sample&large_area=Z011
# google検索
G_SEARCH = "https://www.google.co.jp/search?num=5&q="

def hotpepper_search(keywords, start=1):
    """
    keywords : list of str
    d : dict
    """
    keys = {
        "key": KEY,
        "genre": " ".join(keywords),
        "large_area": "Z011", # 東京
        "start": start,
        "count": COUNT
    }
    url = "{}?{}".format(H_API, urllib.parse.urlencode(keys))
    req = urllib.request.Request(url)
    try:
        with urllib.request.urlopen(req) as res:
            body = res.read()
        d = xmltodict.parse(body)
        return d
    except Exception as e:
        print(e)
        pdb.set_trace()

def google_search(keys):
    """
    keys : list or str
    url : 検索結果最上位のurl
    """
    url = G_SEARCH + " ".join(keys)
    try:
        res = requests.get(url)
        soup = BeautifulSoup(res.text, "html.parser")
        for el in soup.select("h3.r a"):
            title = el.get_text()
            print(title)
            url = dict(urllib.parse.parse_qsl(urllib.parse.urlparse(el.get("href")).query))["q"]
            break
        return url
    except Exception as e:
        print(e)
        return ""

def tabelog_search(url):
    if "tabelog" not in url:
        print("not found tabelog page!")
        return None
    try:
        sleep(3)
        res = requests.get(url)
        soup = BeautifulSoup(res.text, "html.parser")
        score = float(soup.find_all("span", class_="rdheader-rating__score-val-dtl")[0].string)
        print("score : {}".format(score))
        return score
    except Exception as e:
        print(e)
        print("not found tabelog score")
        return None
if __name__=="__main__":
    df = pd.read_csv("data/test.csv", encoding="cp932", header=0).set_index("name")
    shop_ids = set(df["id"])
    keys = ["G005"]
    # keys = ["バル"]
    # keys = ["居酒屋"]
    out = hotpepper_search(keys)
    num = int(out["results"]["results_available"])
    print("{} shops available in hotpepper".format(num))
    shops = []
    scores = []
    ind = 0
    try:
        for ind in range(0,num,COUNT):
            print("{} / {}".format(ind, num))
            out = hotpepper_search(keys, start=ind)
            tmp_shops = []
            scores = []
            for shop in out["results"]["shop"]:
                try:
                    if shop["id"] in shop_ids:
                        print("{} already in data".format(shop["name"]))
                        continue
                    url = google_search(["食べログ", shop["name"]])
                    score = tabelog_search(url)
                    if score is not None:
                        tmp_shops.append(shop)
                        scores.append(score)
                except Exception:
                    pass
            if tmp_shops:
                df2 = pd.DataFrame(tmp_shops)
                df2["score"] = scores
                df2 = df2.set_index("name")
                df = pd.concat((df, df2))
                df.to_csv("test.csv", encoding="cp932")
            
    # out2 = google_search(["信濃町", "煉瓦"])
    except KeyboardInterrupt:
        pass
    df2 = pd.DataFrame(shops)
    df2["score"] = scores
    df2 = df2.set_index("name")
    df3 = pd.concat((df, df2))
    df3.to_csv("test.csv", encoding="cp932")
    pdb.set_trace()
# Out:
# 825 shops available in hotpepper
# 0 / 825
# 神田の肉バル ランプキャップ RUMP CAP 池袋西口店 already in data
# スコール SQUALL 東新宿店 already in data
# MEAT&WINE ワインホールグラマー 池袋 - 池袋/イタリアン [食べログ]
# score : 3.12
# レ クアトロ スタジオーニ （Le quattro stagioni） - 京成上野 ... - 食べログ
# score : 3.33
# 夜カフェ アロハランド 新宿東口店 - 新宿/居酒屋 [食べログ]
# score : 3.05
# フォンティーナ チーズ ダイニング （Fontina Cheese Dining ... - 食べログ
# score : 3.21
# ママ食堂 市ヶ谷店 （ママショクドウ） - 市ヶ谷/居酒屋 [食べログ]
# score : 3.07
# ステーキハウス ハマ 銀座店 - 新橋/ステーキ [食べログ]
# score : 3.19
# LIT STEAK HOUSE GINZA - 東銀座/ステーキ [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 焼肉ダイニング bonbori 渋谷道玄坂店 - 渋谷/焼肉 [食べログ]
# score : 3.06
# 個室ダイニング お肉で宴会 新宿西口店 - 新宿/居酒屋 [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 神田の肉バル ランプキャップ RUMP CAP 銀座店 already in data
# PIZZA&WINE ワインホールグラマー 新宿 - 新宿三丁目 ... - 食べログ
# score : 3.06
# 神田の肉バル ランプキャップ RUMP CAP 渋谷店 already in data
# シュラスコレストラン ALEGRIA shinjuku（アレグリア） - 代々木 - 食べログ
# score : 3.29
# 神田の肉バル ランプキャップ RUMP CAP 田町店 already in data
# 広島風お好み 鉄板焼き 友 - 新宿三丁目/お好み焼き [食べログ]
# score : 3.34
# 巴里 夕顔 - 銀座/鉄板焼き [食べログ]
# score : 3.61
# RYUDUKI TEPPAN - 錦糸町/鉄板焼き [食べログ]
# score : 3.06
# ステーキハウスハマ 六本木本店 - 乃木坂/鉄板焼き [食べログ]
# score : 3.58
# サンマルク 新宿西口ハルク店 - 新宿/洋食 [食べログ]
# score : 3.08
# 溶岩焼肉ダイニング bonbori 新宿店 - 新宿/焼肉 [食べログ]
# score : 3.33
# 上野日和 - 京成上野/居酒屋 [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 肉とチーズバル Golden Meat 新橋店 （ゴールデンミート ... - 食べログ
# could not convert string to float: '-'
# not found tabelog score
# 神田の肉バル ランプキャップ RUMP CAP 新橋店 already in data
# お好み焼きじゃもん 品川店 already in data
# MEAT&WINE ワインホールグラマー 田町 （WINEHALL ... - 食べログ
# score : 3.09
# 升屋 GRILL BAR 品川店 already in data
# 神田の肉バル ランプキャップ RUMP CAP 新宿西口店 already in data
# モータウン MOTOWN already in data
# 個室ダイニング＆肉バル シュラスコ 新宿店 - 西武新宿/居酒屋 [食べログ]
# score : 3.05
# Modern Dinning アニービレッジ 新宿店(居酒屋)＜ネット予約可 ...
# not found tabelog page!
# 惠比壽ビヤホール already in data
# パスタビーノ・ハシヤ 南口店 （PASTAVINO HASHIYA） - 立川 ... - 食べログ
# score : 3.07
# 大衆酒場 『それいけチャラ男。』 - 立川/居酒屋 [食べログ]
# score : 3.06
# 金の蔵 渋谷センター街店 - 渋谷/居酒屋 [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# テキサス 麹町本店 （TEXAS） - 半蔵門/ステーキ [食べログ]
# score : 3.1
# 肉の楽園 - 渋谷/ハンバーグ [食べログ]
# score : 3.0
# インド・ネパール料理 FULBARI （インドネパールリョウリフルバリ） - 蒲田 ...
# score : 3.47
# ひむか - 三軒茶屋/鉄板焼き [食べログ]
# score : 3.22
# 肉の切り方 日本橋本店 - 三越前/焼肉 [食べログ]
# score : 3.58
# ビヤレストラン 銀座ライオン 池袋西口 - 池袋/ビアホール・ビア ... - 食べログ
# score : 3.08
# ラ・パウザ 汐留店 （La Pausa） - 汐留/イタリアン [食べログ]
# score : 3.03
# ジンジャー （Ginger） - 恵比寿/バー・お酒（その他） [食べログ]
# score : 3.05
# グリル・シャトー - 東京/西洋各国料理（その他） [食べログ]
# score : 3.51
# YEBISU BAR 神楽坂店 （エビス バー） - 飯田橋/ビアバー [食べログ]
# score : 3.06
# 听屋 日本橋 （POUND-YA ポンドヤ） - 新日本橋/バル・バール [食べログ]
# score : 3.06
# 東京のおすすめステーキ [食ベログ] - 食べログ
# list index out of range
# not found tabelog score
# ステーキハウス ハマ 目黒店 - 目黒/ステーキ [食べログ]
# score : 3.5
# サンマルク アトレ大森店 - 大森/洋食・欧風料理（その他） [食べログ]
# score : 3.18
# シースケープ テラス・ダイニング （SEASCAPE TERRACE ... - 食べログ
# score : 3.22
# STEAK THE FIRST 日本橋 （ステーキザファースト） - 三越前 ... - 食べログ
# score : 3.05
# STEAK THE FIRST 高田馬場 already in data
# 浜木綿 （ハマユウ） - 台場/鉄板焼き [食べログ]
# score : 3.26
# 四谷 シュラスコ肉ダイニング VINO （ヴィーノ） - 四谷三丁目 ... - 食べログ
# could not convert string to float: '-'
# not found tabelog score
# 鉄板ダイニング Ferrous （フェローズ） - 新宿/鉄板焼き [食べログ]
# score : 3.04
# レストラン イル・ペペ （iL PePe） - 立川北/イタリアン [食べログ]
# score : 3.0
# 肉炭バル MATOIYA - 表参道/バル・バール [食べログ]
# score : 3.05
# ベッラベーラ 錦糸町店 already in data
# ガーデン ダイニング （GARDEN DINING） - 台場/バイキング [食べログ]
# score : 3.1
# HAYASHIYA （ハヤシヤ） - 新宿/ステーキ [食べログ]
# score : 3.06
# 蘭麻 （ランマ） - 町田/ステーキ [食べログ]
# score : 3.51
# ポレール （POLAIRE） - 成城学園前/ステーキ [食べログ]
# score : 3.07
# ごち屋 本郷店 - 食べログ
# score : 3.01
# やっぱりあさくま 九段下店 - 九段下/ステーキ [食べログ]
# score : 3.08
# ステラ （Stella） - 新宿三丁目/バイキング [食べログ]
# score : 3.0
# シャングリラ （Shangri-La） - 虎ノ門/フレンチ [食べログ]
# score : 3.07
# レッドロブスター アクアシティお台場店 （Red Lobster） - 台場 ... - 食べログ
# score : 3.33
# ラルース （Larousse） - 浅草/洋食 [食べログ]
# score : 3.56
# サンマルク グランデュオ蒲田店 - 蒲田/洋食・欧風料理（その他） [食べログ]
# score : 3.07
# Jamming Dining （ジャミング ダイニング） - 町田/ダイニングバー [食べログ]
# score : 3.18
# テキサス 新宿野村ビル店 （TEXAS） - 西新宿/ステーキ [食べログ]
# score : 3.0
# 黒船亭 （クロフネテイ） - 上野広小路/洋食 [食べログ]
# score : 3.58
# 焼肉 だん - 西武新宿/焼肉 [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 鉄板焼 明日香 （てっぱんやき あすか） - 立川北/鉄板焼き [食べログ]
# score : 3.06
# 一場 already in data
# チョッパー （CHOPPER） - 向ヶ丘遊園/ステーキ [食べログ]
# score : 3.07
# DANRAN亭 炭火鉄板バル already in data
# ビストロ DOMANNAKA already in data
# 神田の肉バル ランプキャップ RUMP CAP 赤羽店 already in data
# エトワール （l'Etoile） - 新橋/バイキング [食べログ]
# score : 3.18
# ステーキモンスター 荻窪 already in data
# ベルテンポ （Beltempo） - 飯田橋/イタリアン [食べログ]
# score : 3.28
# さつま福永牧場直営 牛串 ギュウドウ！ GEMS三軒茶屋店 ... - 食べログ
# score : 3.02
# チンパンジー Chimpanzee already in data
# 【移転】最高おにくセンター - 上板橋/ステーキ [食べログ]
# score : 3.06
# キャプテン カウ - 十条/ステーキ [食べログ]
# score : 3.06
# DANTE （テッパンヤキ・ダンテ） - 赤坂/鉄板焼き [食べログ]
# score : 3.31
# 大衆ビストロ Lit - 赤羽岩淵/ビストロ [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# ハンバーグ ストロング （Hamburg Stolong） - 秋葉原/ハンバーグ [食べログ]
# score : 3.0
# 銀座ライオン 青山一丁目店 already in data
# 听屋 吉祥寺店 （POUND-YA ポンドヤ） - 吉祥寺/ステーキ [食べログ]
# score : 3.37
# クラウンハウス Crown House already in data
# レストランせんごく 本郷店 already in data
# Tokyo 石焼鉄板 プライベートダイニング えんじゃ - 赤羽/居酒屋 [食べログ]
# score : 3.05
# プチアーナ （PETIT ANNA） - 志村三丁目/イタリアン [食べログ]
# score : 3.07
# トラットリア デニーロ （Trattoria DE NIRO） - 茅場町/イタリアン [食べログ]
# score : 3.03
# 東京のおすすめグルメ情報 (シュリンプカクテル) [食ベログ] - 食べログ
# list index out of range
# not found tabelog score
# 銀座ライオン ゲートシティ大崎店 - 大崎/ビアホール・ビア ... - 食べログ
# score : 3.02
# NORI （ノリ） - 白金高輪/イタリアン [食べログ]
# score : 3.05
# c:\anaconda\lib\site-packages\ipykernel_launcher.py:108: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# 100 / 825
# NORI （ノリ） - 白金高輪/イタリアン [食べログ]
# score : 3.05
# 銀座ライオン 霞が関コモンゲート店 - 虎ノ門/ビアホール・ビア ... - 食べログ
# score : 3.07
# 神戸ビーフ食品直営店 鉄板焼 銀座888 - 汐留/鉄板焼き [食べログ]
# score : 3.04
# レッドロブスター 上板橋店 （Red Lobster） - 上板橋/シーフード [食べログ]
# score : 3.51
# 焼肉ほりたん - 銀座/焼肉 [食べログ]
# score : 3.52
# 銀座 ドギーズ already in data
# テルポリート from ユキノヤ （teruporito from ユキノヤ） - 板橋 ... - 食べログ
# score : 3.05
# 黒毛和牛専門店ステーキモンスター 日本橋黒桜 - 水天宮前 ... - 食べログ
# score : 3.09
# アルトマーレ - 池尻大橋/イタリアン [食べログ]
# score : 3.03
# 赤羽 union already in data
# オイスターテーブル Oystar Table 浜松町店 already in data
# コルザ - 銀座/鉄板焼き [食べログ]
# score : 3.58
# 銀座ライオン 上野西郷会館店 - 京成上野/ビアホール・ビア ... - 食べログ
# score : 3.07
# ステーキダイニング 大地の恵み 上野御徒町店 already in data
# 東京のおすすめステーキ [食ベログ] - 食べログ
# list index out of range
# not found tabelog score
# 鉄板焼き かいか already in data
# エイジング・ビーフ TOKYO 新宿三丁目店 - 食べログ
# score : 3.51
# すうぷ屋 新宿ミロード店 （スウプヤ） - 新宿/スープ [食べログ]
# score : 3.1
# 鉄板個室ダイニング ぽんぽこ八兵衛 - 門前仲町/お好み焼き [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# ステーキ パンドラ 匠 （タクミ） - 新宿/ステーキ [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# スープカリーシーエス スカイツリー店 - 業平橋/スープカレー [食べログ]
# score : 3.01
# 三代目 圭 - 上野御徒町/鉄板焼き [食べログ]
# score : 3.36
# サイゼリヤ 京王八王子駅ビル店 - 京王八王子/ファミレス [食べログ]
# score : 3.0
# 浅草グリルバーグ - 田原町/ハンバーグ [食べログ]
# score : 3.22
# 新宿 夜景 M PRIME 野村ビル49階 - 西新宿/ダイニングバー [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# PIZZA SALVATORE CUOMO サブナード （ピッツァサルヴァトーレクオモ ...
# score : 3.1
# バズ グリル （BUZZ's GRILL） - 西葛西/ハンバーグ [食べログ]
# score : 3.18
# the 肉丼の店 だいにんぐ 高田馬場店 already in data
# Belon Belon Boo already in data
# グリロジー バー＆グリル （GRILLOGY BAR AND GRILL ... - 食べログ
# score : 3.13
# PIZZA SALVATORE CUOMO 聖蹟桜ヶ丘 （ピッツァ ... - 食べログ
# score : 3.06
# 鉄板焼きステーキ あずま （テッパンヤキステーキアズマ ... - 食べログ
# score : 3.02
# アリオッソ - 茅場町/洋食 [食べログ]
# score : 3.04
# はやしや - 新宿/洋食 [食べログ]
# score : 3.11
# レストラン・ランス・ヤナギダテ （Restaurant REIMS ... - 食べログ
# score : 3.58
# 池袋 鉄板焼 焔 （エン） - 池袋/鉄板焼き [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# マイアミパティオ 大塚駅北口店 （Miami Patio） - 大塚/ワインバー [食べログ]
# score : 3.03
# 鉄板焼 ろじ - 錦糸町/鉄板焼き [食べログ]
# score : 3.33
# ビアホール ビヤケラー東京 新橋銀座口店 already in data
# 牛角 秋津店 already in data
# GOOD MORNING CAFE & GRILL キュウリ （グッドモーニングカフェ ...
# score : 3.24
# La Fiesta （ラ フェスタ） - 九段下/イタリアン [食べログ]
# score : 3.0
# 蔵元 渋谷店 - 渋谷/焼肉 [食べログ]
# score : 3.47
# コマイチ アンド カフェ （KOMAICHI & CAFE） - 駒沢大学/カフェ [食べログ]
# score : 3.08
# マリカ 本郷店 （MALIKA） - 本郷三丁目/インド料理 [食べログ]
# score : 3.06
# オムライスキッチン AWAAWA already in data
# キュイジーヌ （CUISINE） - 池尻大橋/洋食 [食べログ]
# score : 3.04
# ハラペコステーキ 新宿本店 - 西武新宿/ステーキ [食べログ]
# score : 3.06
# ステーキ・鉄板焼 裕 （ひろ） - 浅草/ステーキ [食べログ]
# score : 3.03
# 東京らっきょブラザーズ - 早稲田/スープカレー [食べログ]
# score : 3.57
# 雅亭 （【旧店名】ステーキハウス 照） - 日本橋/ステーキ [食べログ]
# score : 3.08
# 炭焼きステーキくに 赤坂店 - 赤坂見附/ステーキ [食べログ]
# score : 3.18
# ステーキ The 高橋 （ステーキ ザ タカハシ） - 綾瀬/ステーキ [食べログ]
# score : 3.07
# マトリョーシカ マルイシティ上野店 - 上野/ロシア料理 [食べログ]
# score : 3.11
# 炭屋 - 塩釜口/焼肉 [食べログ]
# score : 3.33
# KEN （ケン） - 代々木/洋食 [食べログ]
# score : 3.04
# 鉄板焼grow （グロウ） - 春日/鉄板焼き [食べログ]
# score : 3.46
# crab台風。 - 人形町/ラーメン [食べログ]
# score : 3.53
# 市ヶ谷テキサス （TEXAS） - 市ヶ谷/ステーキ [食べログ]
# score : 3.07
# ビフテキのカワムラ 銀座店 - 銀座/ステーキ [食べログ]
# score : 3.72
# 円居 池袋 （MADOy） - 池袋/鉄板焼き [食べログ]
# score : 3.06
# ごはんや さらしな - 西八王子/そば [食べログ]
# score : 3.01
# アッ！そうだ ステーキ 水天宮前店 - 食べログ
# score : 3.0
# 鉄板焼 ORCA 渋谷店 （オルカ） - 渋谷/鉄板焼き [食べログ]
# score : 3.05
# 鉄板焼 山海亭 （てっぱんやき さんかいてい） - 池袋/鉄板焼き [食べログ]
# score : 3.0
# デイトリップ （DAY TRIP） - 八王子/アジア・エスニック料理 ... - 食べログ
# score : 3.05
# 渋谷で真の山形牛を扱うお店 加藤牛肉店シブツウ - 食べログ
# score : 3.34
# 旬菜ステーキ処 らいむらいと （シュンサイステーキドコロ ライム ... - 食べログ
# score : 3.58
# 東京のグルメ・レストランガイド [食べログ]
# list index out of range
# not found tabelog score
# Les deux Bleue （レドゥブルー） - 豊洲/カフェ [食べログ]
# score : 3.44
# ビフテキのカワムラ 六本木店 - 六本木/ステーキ [食べログ]
# score : 3.18
# 鉄板Diner JAKEN 新宿店（テッパンダイナー ジャケン） - 新宿 ... - 食べログ
# score : 3.48
# グリル満天星 麻布十番 日本橋三越店 - 三越前/洋食 [食べログ]
# score : 3.17
# わかき - 浅草橋/ステーキ [食べログ]
# score : 3.12
# ドミナント （DOMINANT） - 表参道/鉄板焼き [食べログ]
# score : 3.06
# バンボリーナ - 茅場町/洋食 [食べログ]
# score : 3.13
# グラスコート （Glass Court） - 都庁前/バイキング [食べログ]
# score : 3.52
# ふらんす亭 池袋サンシャイン60階通り店 - 池袋/ステーキ [食べログ]
# score : 3.06
# ステーキハンバーグ＆サラダバーけん 町田成瀬店 （FC店 ... - 食べログ
# score : 3.0
# 紅矢 京王八王子店 - 京王八王子/ハンバーグ [食べログ]
# score : 3.0
# 1129 by Ogawa （イチイチニイキュウ バイ オガワ） - お台場 ... - 食べログ
# score : 3.12
# 樹林 （jurin） - 都庁前/洋食・欧風料理（その他） [食べログ]
# score : 3.0
# ビッグシェフ お台場・デックス東京ビーチ - 食べログ
# score : 3.05
# 炭焼ステーキくに 両国店 - 両国/ステーキ [食べログ]
# score : 3.17
# 鉄板Diner JAKEN 池袋本店 （ジャケン） - 池袋/ステーキ [食べログ]
# score : 3.41
# パークストリート （PARK STREET） - 吉祥寺/バイキング [食べログ]
# score : 3.0
# すきずき - 田原町/ステーキ [食べログ]
# score : 3.51
# ペーパームーン （Paper Moon） - 小岩/洋食 [食べログ]
# score : 3.0
# 天狗 - 錦糸町/焼肉 [食べログ]
# score : 3.53
# スープカレー屋 鴻 神田駿河台店（スープカレーヤ オオドリー ... - 食べログ
# score : 3.58
# 築地 さとう （つきじさとう） - 東銀座/懐石・会席料理 [食べログ]
# score : 3.58
# ヴァション/シアトルズベストコーヒー 芝公園店 （【旧店名 ... - 食べログ
# score : 3.22
# 鶴亀樓 原宿 （ツルカメロウ） - 明治神宮前/ステーキ [食べログ]
# score : 3.0
# 炭焼ステーキくに 新小岩店 - 新小岩/ステーキ [食べログ]
# score : 3.08
# 肉の村山 錦糸町マルイ店 - 錦糸町/ハンバーグ [食べログ]
# score : 3.06
# レストラン ラグー （RESTAURANT RAGOUT） - 水天宮前/洋食 [食べログ]
# score : 3.24
# 花瑠音 （ かるね ） - ひばりヶ丘/ステーキ [食べログ]
# score : 3.06
# アッそうだ!ステーキ 木場店 - 木場/ステーキ [食べログ]
# score : 3.06
# 鉄板焼 きだんち - 食べログ
# score : 3.19
# 3匹の子ぶた （サンビキノコブタ） - 門前仲町/ステーキ [食べログ]
# score : 3.37
# 200 / 825
# 洋食レストラン いせや - 府中/洋食 [食べログ]
# score : 3.04
# マヌエル・コジーニャ・ポルトゲーザ 渋谷店 （Manuel Cozinha - 食べログ
# score : 3.58
# ザ ミート ロッカー （The Meat Locker） - 三越前/ステーキ [食べログ]
# score : 3.51
# ステーキ＆タコス・テキサス オペラシティ店 （TEXAS） - 初台 ... - 食べログ
# score : 3.08
# アウトバックステーキハウス 品川高輪店 （OUTBACK ... - 食べログ
# score : 3.37
# 門前仲町駅のおすすめカフェ・喫茶 [食ベログ] - 食べログ
# list index out of range
# not found tabelog score
# 鉄板焼 徳吉 （テッパンヤキトクヨシ） - 浅草/鉄板焼き [食べログ]
# score : 3.57
# NIKU NIKU STADIUM NO.8 （ニクニクスタジアムナンバー ... - 食べログ
# score : 3.02
# となりのキッチン市原亭 - 代田橋/洋食 [食べログ]
# score : 3.03
# 鉄板バル AKICHI （アキチ） - 調布/鉄板焼き [食べログ]
# score : 3.0
# レッドロブスター 上池台店 （Red Lobster） - 西馬込/シーフード [食べログ]
# score : 3.17
# 大坂鉄板焼 銀座 鉄十 - 銀座/鉄板焼き [食べログ]
# score : 3.23
# ベリーベリースープ JR田町駅前店 - 田町/シチュー [食べログ]
# score : 3.0
# 加藤牛肉店 銀座 （かとうぎゅうにくてん） - 銀座/ステーキ [食べログ]
# score : 4.05
# KOTAN cocotte＆Grill （コタン） - 府中/バル・バール [食べログ]
# score : 3.06
# 大木屋匠 - 三越前/もんじゃ焼き [食べログ]
# score : 3.58
# はと屋 （ハトヤ） - 新橋/洋食 [食べログ]
# score : 3.55
# cafe Hohokam （カフェ ホホカム） - 明治神宮前/ハンバーガー [食べログ]
# score : 3.51
# ハドソン （Hudson） - 東中野/アメリカ料理 [食べログ]
# score : 3.05
# ライアー - 渋谷/フレンチ [食べログ]
# score : 3.51
# GRILL UKAI MARUNOUCHI （グリルうかい 丸の内店） - 二 ... - 食べログ
# score : 3.68
# レストランあづま - 銀座/洋食 [食べログ]
# score : 3.52
# 日乃屋カレー 溜池山王店 - 溜池山王/カレーライス [食べログ]
# score : 3.08
# TWO ROOMS GRILL｜BAR - 表参道/ステーキ [食べログ]
# score : 3.58
# Oyster Bar ジャックポット 国際ビル - 日比谷/シーフード [食べログ]
# score : 3.09
# HIRO （ヒロ） - 新橋/ダイニングバー [食べログ]
# score : 3.06
# ゴッチーズビーフ Gottie's BEEF 吉祥寺店 already in data
# 和洋食屋 いいま - 浅草/洋食 [食べログ]
# score : 3.09
# 鉄板焼 屯 （タムロ） - 江戸川橋/ステーキ [食べログ]
# score : 3.37
# キッチン桑の樹 - 町屋駅前/洋食 [食べログ]
# score : 3.01
# ゴーゴーカレー 池袋東口スタジアム - 池袋/カレーライス [食べログ]
# score : 3.05
# ルガリーコ （Lugari-Co） - 竹ノ塚/ワインバー [食べログ]
# score : 3.03
# ドン コナ コネリー （DON CONA CONERY） - 五反田/イタリアン [食べログ]
# score : 3.19
# 薬膳スープカレー・シャナイア （Shania） - 恵比寿/スープカレー [食べログ]
# score : 3.58
# ビヤホール 銀座ライオン 丸の内センタービル店 - 東京 ... - 食べログ
# score : 3.06
# スティック＆スプーン （STICK & SPOON） - 御徒町/ハンバーグ [食べログ]
# score : 3.0
# エッグセレント （eggcellent） - 六本木/カフェ [食べログ]
# score : 3.26
# ソース ポット （SAUCE POT） - 京成立石/カレーライス [食べログ]
# score : 3.06
# 霜降りハンバーグとステーキの店 鉄重 町田店 - 町田/ハンバーグ [食べログ]
# score : 3.39
# インペリアルバイキング サール （THE IMPERIAL VIKING SAL ... - 食べログ
# score : 3.63
# カタマリ肉ステーキ＆サラダバー にくスタ 南蒲田店 - 京急蒲田 ... - 食べログ
# score : 3.05
# カフェ・ド・ジェノワーズ 東府中店 （Cafe de Genoise） - 東 ... - 食べログ
# score : 3.08
# ワインホールグラマー 銀座 （WINE HALL GLAMOUR） - 新橋 ... - 食べログ
# score : 3.0
# マヌエル・カーザ・デ・ファド （Manuel Casa de Fado） - 四ツ谷 ... - 食べログ
# score : 3.44
# 昭島駅のおすすめインドカレー [食ベログ] - 食べログ
# list index out of range
# not found tabelog score
# ガッツソウル 高田馬場店 - 高田馬場/焼肉 [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 鉄板焼き ステーキ 湛山 - 西武新宿/ステーキ [食べログ]
# score : 3.58
# ミートギャラリー エチゴヤ （MEAT GALLERY Echigoya ... - 食べログ
# score : 3.0
# 神楽坂 てっぱんや - 飯田橋/鉄板焼き [食べログ]
# score : 3.32
# レッドロブスター 練馬関町店 （Red Lobster） - 上石神井 ... - 食べログ
# score : 3.07
# レッドロブスター 北小岩店 （Red Lobster） - 小岩/シーフード [食べログ]
# score : 3.08
# NAGAOKA SAKUMO - 六本木/鉄板焼き [食べログ]
# score : 3.52
# Steak Dining G4U - 新宿西口/ステーキ [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 山彦 （てっぱんやき やまひこ） - 飯田橋/鉄板焼き [食べログ]
# score : 3.07
# ステーキハウス TERA - 阪東橋/ステーキ [食べログ]
# score : 3.42
# カレーの文化 - 荏原中延/カレーライス [食べログ]
# score : 3.03
# カタマリ肉ステーキ＆サラダバー にくスタ 羽田大鳥居店 ... - 食べログ
# could not convert string to float: '-'
# not found tabelog score
# ヴァン ア ビブリオテイク （Vin a Bibliotheque） - 東銀座/ビストロ [食べログ]
# score : 3.08
# 嘉門 （かもん） - 日比谷/鉄板焼き [食べログ]
# score : 3.65
# ロイヤルスターシップ （Royal Starship） - 巣鴨/洋食 [食べログ]
# score : 3.04
# ノックトーン 銀座店 （NOKKTON） - 新橋/カフェ [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# SAMURAI dos Premium Steak House 八重洲鉄鋼ビル店 ... - 食べログ
# score : 3.53
# 『堂々の24時間営業』by キー君 : ゆで太郎 新木場1丁目店 ... - 食べログ
# score : 3.0
# ビヤレストラン 銀座ライオン アトレ恵比寿店 - 食べログ
# score : 3.07
# 六本木うかい亭 - 六本木/鉄板焼き [食べログ]
# score : 3.61
# ルース クリス ステーキハウス （RUTH'S CHRIS STEAK ... - 食べログ
# score : 3.59
# LOJI （ロジ） - 三鷹/鉄板焼き [食べログ]
# score : 3.06
# 定谷 - 入谷/ステーキ [食べログ]
# score : 4.13
# 銀座うかい亭 （ぎんざうかいてい） - 東銀座/鉄板焼き [食べログ]
# score : 4.23
# TOKYO ステーキ丼 ガブス 本駒込本店 - 本駒込/丼もの（その他） [食べログ]
# score : 3.43
# モアナキッチンカフェ 新宿タカシマヤタイムズスクエア店 - 食べログ
# score : 3.0
# 神田ビストロ style 4号店 - 神田/バル・バール [食べログ]
# score : 3.06
# 熟成牛ステーキ専門店 Gottie's BEEF GEMS大門 （ゴッチーズビーフ ...
# score : 3.07
# グランド・セントラル・オイスターバー&レストラン 品川店 ... - 食べログ
# score : 3.58
# 甚六 （じんろく） - 広尾/鉄板焼き [食べログ]
# score : 3.09
# 三浦のハンバーグ （ミウラノハンバーグ） - 池袋/ハンバーグ [食べログ]
# score : 3.06
# キッチン男の晩ごはん 女の昼ごはん - 江古田/定食・食堂 [食べログ]
# score : 3.0
# ミキスケ - 小伝馬町/ステーキ [食べログ]
# score : 3.39
# 鉄板酒房 森 - 大森/鉄板焼き [食べログ]
# score : 3.11
# くすのき亭 - 花小金井/洋食 [食べログ]
# score : 3.24
# キュイズィーヌ プティ・ボワ （一光） - 八丁堀/鉄板焼き [食べログ]
# score : 3.08
# ステーキ屋 暖手 秋葉原本店 - 末広町/ステーキ [食べログ]
# score : 3.1
# 表参道うかい亭 - 明治神宮前/鉄板焼き [食べログ]
# score : 4.0
# アカス （Aakash） - 浅草橋/インド料理 [食べログ]
# score : 3.0
# ル・パン・コティディアン 東京ミッドタウン店 （Le Pain ... - 食べログ
# score : 3.52
# シチューとカレーの専門店 銀座 古川 - 銀座/洋食 [食べログ]
# score : 3.59
# こがも亭 森野店 - 町田/ステーキ [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# ステーキ ヨシノ （YOSHINO） - 神保町/ステーキ [食べログ]
# score : 3.06
# 鉄板焼 燈 AkaRi （燈 あかり） - 新橋/鉄板焼き [食べログ]
# score : 3.06
# 桃の実 （モモノミ） - 本郷三丁目/ビストロ [食べログ]
# score : 3.59
# 鉄板焼 さざんか （テッパンヤキサザンカ） - 六本木一丁目 ... - 食べログ
# score : 3.06
# なかどや・ジーマ 堀切菖蒲園(洋食)＜ネット予約可＞ | ホットペッパーグルメ
# not found tabelog page!
# タツヤ食堂 - 井荻/洋食・欧風料理（その他） [食べログ]
# score : 3.04
# 熟成牛ステーキ専門店 Gottie's BEEF 銀座ベルビア館 （ゴッチーズビーフ ...
# score : 3.18
# レストラン オーヴ - 青山一丁目/洋食 [食べログ]
# score : 3.03
# リバティーハウス （Café LIBERTY HOUSE） - ときわ台/カレー ... - 食べログ
# score : 3.04
# エル・アミーゴ - 長原/ステーキ [食べログ]
# score : 3.18
# 練馬展望レストラン - 練馬/洋食 [食べログ]
# score : 3.05
# MARINA RESTAURANT TRIM （マリーナレストラン トリム ... - 食べログ
# score : 3.1
# しこたま。 （shikotama） - 飯田橋/居酒屋 [食べログ]
# score : 3.32
# 300 / 825
# グラムズカフェ （Grahm's Cafe） - 東京/カフェ [食べログ]
# score : 3.53
# 旬熟成 六本木店 - 麻布十番/ステーキ [食べログ]
# score : 3.59
# ステーキハウス ブル （ステーキハウス BULL） - 西大島/ステーキ [食べログ]
# score : 3.06
# アウトバックステーキハウス 池袋店 （OUTBACK ... - 食べログ
# score : 3.2
# リビエール - 下丸子/洋食 [食べログ]
# score : 3.0
# すて～き茶寮 ひみ呼 already in data
# 銀座ライオン 恵比寿ガーデンプレイスグラススクエア店 - 食べログ
# score : 3.06
# 洋食や 三代目 たいめいけん - 上野/洋食 [食べログ]
# score : 3.54
# 銀座一位 - 新橋/ステーキ [食べログ]
# score : 3.07
# ベッラヴィスタ （BELLA VISTA【旧店名】ベルヴュー） - 永田町 ... - 食べログ
# score : 3.58
# 青山牛彩 （あおやまぎゅうさい） - 青山一丁目/鉄板焼き [食べログ]
# score : 3.58
# Cave+SRh （カーヴプラスエスアールエイチ） - 新橋/バー [食べログ]
# score : 3.12
# 六本木モンシェルトントン （Mon cher ton ton） - 六本木/鉄板焼き [食べログ]
# score : 3.58
# アカネコ - 浅草橋/バル・バール [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# シズラー 新宿三井ビル店 （Sizzler） - 都庁前/ファミレス [食べログ]
# score : 3.42
# 自然食カフェ すぴか - 錦糸町/カフェ [食べログ]
# score : 3.08
# 大安くらぶ （だいあんくらぶ） - 東京/鉄板焼き [食べログ]
# score : 3.07
# TOYO （東洋 トウヨウ） - 日本橋/洋食 [食べログ]
# score : 3.25
# 嘉山 - 麻布十番/鉄板焼き [食べログ]
# score : 3.06
# 肉の大山 （おおやま） - 上野/コロッケ・フライ [食べログ]
# score : 3.57
# ぼんのてい already in data
# ALLT GOTT （アルトゴット） - 吉祥寺/西洋各国料理（その他） [食べログ]
# score : 3.54
# CARNE BAR KATETE 大門店 - 御成門/バル・バール [食べログ]
# score : 3.43
# 東京のおすすめステーキ [食ベログ] - 食べログ
# list index out of range
# not found tabelog score
# みかわや - 銀座/洋食 [食べログ]
# score : 3.59
# キッチン長崎 - 東長崎/定食・食堂 [食べログ]
# score : 3.07
# はしぐち亭 - 経堂/洋食 [食べログ]
# score : 3.12
# カフェメゾンドケー （Cafe. maison de K.） - 九品仏/カフェ [食べログ]
# score : 3.06
# MEAT 肉男 MAN （ミートマン） - 六本木/居酒屋 [食べログ]
# score : 3.52
# 坂の上ホタル - 代々木上原/ビストロ [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 『穴場ですよ』by まかいほ : フィッシュ （FISH） - 新宿/インド料理 [食べログ]
# score : 3.57
# 神田たまごけん 経堂店 - 経堂/オムライス [食べログ]
# score : 3.04
# こやまん家 - 新橋/洋食 [食べログ]
# could not convert string to float: '-'
# not found tabelog score
# 厳選洋食さくらい （ゲンセンヨウショクサクライ） - 上野広小路 ... - 食べログ
# score : 3.59
# 榎本ハンバーグ研究所 （【旧店名】コーヒーエノモト） - 上中里 ... - 食べログ
# score : 3.52
# すずや 北新宿店 - 西新宿/洋食 [食べログ]
# score : 3.09
# かつ敏 綾瀬店 - 亀有/とんかつ [食べログ]
# score : 3.07
# Cafe ASPEN （カフェ アスペン） - 草津町その他/ピザ [食べログ]
# score : 3.03
# ダイナマイト - 地下鉄成増/ステーキ [食べログ]
# score : 3.02
# キッチンさくらい - 御徒町/洋食 [食べログ]
# score : 3.58
# ジュノン - 鷹の台/洋食 [食べログ]
# score : 3.2
# カタマリ肉ステーキ＆サラダバー にくスタ 府中若松店 - 多磨 ... - 食べログ
# score : 3.12
# スモークバーベキュー さくら - 神田/バーベキュー [食べログ]
# score : 3.24
# 【移転】オードブルハウス ローズマリー - 桜台/洋食 [食べログ]
# score : 3.04
# ラケル 吉祥寺店 - 吉祥寺/オムライス [食べログ]
# score : 3.0
# マンハッタングリル - 二重橋前/洋食 [食べログ]
# score : 3.13
# 日乃屋カレー 初台店 - 初台/カレーライス [食べログ]
# score : 3.0
# Meat Winery （ミートワイナリー） - 秋葉原/ステーキ [食べログ]
# score : 3.21
# レストラン神谷 - 聖蹟桜ヶ丘/しゃぶしゃぶ [食べログ]
# score : 3.08
# レストラン じぇびあん （Jbien） - 後楽園/洋食 [食べログ]
# score : 3.02
# 鉄板焼 すみだ （テッパンヤキスミダ） - 水天宮前/鉄板焼き [食べログ]
# score : 3.5
# オールドステーション 東京 - 大手町/ビアホール・ビアレストラン [食べログ]
# score : 3.51
# ディナ ギャン ドス （Dina Gyang �U） - 三田/イタリアン [食べログ]
# score : 3.01
# シェフズ ライブ キッチン （Chef's Live Kitchen） - 竹芝 ... - 食べログ
# score : 3.57
# KENT （ケント） - 町田/レストラン（その他） [食べログ]
# score : 3.04
# 肉や しるし - 四ツ谷/居酒屋 [食べログ]
# score : 3.35
# アジアンレストラン&バー トマト 南大泉店 ... - 食べログ
# score : 3.04
# レッドロブスター 武蔵野関前店 （Red Lobster） - 武蔵境 ... - 食べログ
# score : 3.13
# マルシェ・オー・ヴァン・ヤマダ （MARCHE AUX VINS ... - 食べログ
# score : 3.12
# グラシア （食堂酒場Gracia） - 浅草橋/洋食 [食べログ]
# score : 3.6
# 自由が丘バーガー 自由が丘店 （JIYUGAOKA BURGER ... - 食べログ
# score : 3.58
# 日乃屋カレー 茅場町店 - 八丁堀/カレーライス [食べログ]
